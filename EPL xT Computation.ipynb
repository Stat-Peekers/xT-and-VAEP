# %% [markdown]
# # This is based on Markov model (Memoryless)
# Memoryless models do not take into account the actions before and after the current action

# %% [markdown]
# # Import Libraries

# %%
import pandas as pd

# %% [markdown]
# # Get Data

# %%
cols_for_xt = ['minute', 'second', 'teamId', 'teamName', 'h_a',
               'x', 'y', 'expandedMinute', 'period', 'type', 'outcomeType', 'score',
               'playerId', 'playerName', 'endX', 'endY', "isShot", "isOwnGoal"]

# %%
xt_df = pd.read_csv("../data/Premier League/2021-2022/event_data.csv", low_memory=False)

# %%
xt_grid_df = pd.read_csv("../data/xT_Grid.csv", header=None)
xt_grid_df
# Out:
#           0         1         2         3         4         5         6   \
# 0   0.000828  0.002543  0.003652  0.007795  0.013633  0.020894  0.025403
# 1   0.000841  0.003283  0.004089  0.008307  0.013324  0.018302  0.022191
# 2   0.000703  0.003383  0.003456  0.008025  0.013326  0.018250  0.020604
# 3   0.001702  0.005673  0.006295  0.012162  0.015491  0.022664  0.027817
# 4   0.003844  0.006209  0.007815  0.010247  0.015109  0.022571  0.020372
# 5   0.018321  0.011010  0.017235  0.007616  0.014741  0.019497  0.011526
# 6   0.017724  0.009210  0.014099  0.007174  0.014697  0.021808  0.010956
# 7   0.003501  0.004641  0.006628  0.008510  0.014032  0.019352  0.019798
# 8   0.001488  0.004702  0.005325  0.010703  0.018179  0.021458  0.025836
# 9   0.000615  0.002658  0.002978  0.006945  0.012873  0.016493  0.016510
# 10  0.000921  0.002626  0.003449  0.006176  0.010964  0.014891  0.023583
# 11  0.000794  0.002249  0.003352  0.006735  0.011446  0.016679  0.021396
#
#           7         8         9         10        11        12        13  \
# 0   0.023597  0.029002  0.054983  0.065006  0.087954  0.100036  0.092737
# 1   0.017617  0.024070  0.038428  0.054961  0.073590  0.082512  0.065993
# 2   0.018121  0.022990  0.037736  0.052428  0.075394  0.063609  0.032408
# 3   0.027618  0.028053  0.044331  0.054082  0.064160  0.054753  0.028039
# 4   0.017351  0.018179  0.030381  0.044285  0.045240  0.026979  0.053293
# 5   0.028151  0.033493  0.013868  0.035316  0.036558  0.034913  0.078975
# 6   0.028359  0.028664  0.012611  0.035017  0.036049  0.027309  0.069071
# 7   0.016509  0.020460  0.027020  0.047117  0.040916  0.026694  0.036770
# 8   0.023383  0.029237  0.046570  0.051638  0.066484  0.045567  0.017753
# 9   0.016487  0.019279  0.033610  0.044688  0.067980  0.056511  0.034807
# 10  0.014974  0.020657  0.039506  0.046839  0.064833  0.075672  0.065542
# 11  0.017503  0.024707  0.047143  0.059150  0.076513  0.085787  0.095936
#
#           14        15
# 0   0.086888  0.280268
# 1   0.071766  0.055461
# 2   0.052167  0.048856
# 3   0.044991  0.062750
# 4   0.069674  0.077692
# 5   0.180704  0.336940
# 6   0.141684  0.319632
# 7   0.078882  0.058132
# 8   0.042561  0.067027
# 9   0.057829  0.047970
# 10  0.069095  0.043029
# 11  0.079671  0.276350

# %% [markdown]
# # Data Cleaning

# %% [markdown]
# ## Keep only required columns
# This is for memory management

# %%
xt_df = xt_df[cols_for_xt]

# %% [markdown]
# # Compute xT for all players

# %% [markdown]
# ## Keep all successful move and shoot actions

# %%
xt_df[xt_df["isShot"]]["outcomeType"].unique()
# Out:
# array(['Successful'], dtype=object)

# %%
xt_df.loc[(xt_df["isShot"] & (xt_df["isOwnGoal"] != True))]["type"]
# Out:
# 22          SavedShot
# 197       MissedShots
# 206        ShotOnPost
# 283       MissedShots
# 376              Goal
#              ...
# 336533      SavedShot
# 336541      SavedShot
# 336656      SavedShot
# 336796    MissedShots
# 336835      SavedShot
# Name: type, Length: 5560, dtype: object

# %%
xt_df.loc[(xt_df["type"].isin(["Pass", "TakeOn"])) | (xt_df["isShot"] & (xt_df["isOwnGoal"] != True))]["type"]
# Out:
# 2         Pass
# 3         Pass
# 4         Pass
# 5         Pass
# 6         Pass
#           ...
# 336968    Pass
# 336971    Pass
# 336972    Pass
# 336973    Pass
# 336974    Pass
# Name: type, Length: 225638, dtype: object

# %%
xt_action_df = xt_df.loc[(xt_df["type"].isin(["Pass", "TakeOn"]))
                         & (xt_df["outcomeType"] == "Successful")
                         & (xt_df["x"].notnull())
                         & (xt_df["y"].notnull())
                         & (xt_df["endX"].notnull())
                         & (xt_df["endY"].notnull())].copy(deep=True)

# %%
xt_action_df[xt_action_df["endX"].isnull()]["type"]
# Out:
# Series([], Name: type, dtype: object)

# %% [markdown]
# ## Compute the bins

# %%
xt_grid_df.shape
# Out:
# (12, 16)

# %%
xt_rows = xt_grid_df.shape[0]
xt_cols = xt_grid_df.shape[1]

# %%
xt_action_df["x1_bin"] = pd.cut(xt_action_df["x"], bins=xt_cols, labels=False)
xt_action_df["y1_bin"] = pd.cut(xt_action_df["y"], bins=xt_rows, labels=False)
xt_action_df["x2_bin"] = pd.cut(xt_action_df["endX"], bins=xt_cols, labels=False)
xt_action_df["y2_bin"] = pd.cut(xt_action_df["endY"], bins=xt_rows, labels=False)

# %% [markdown]
# # Calculate final xT for each player

# %%
xt_action_df["start_zone_xT"] = xt_action_df[["x1_bin", "y1_bin"]].apply(lambda x: xt_grid_df.loc[x[1], x[0]], axis=1)
xt_action_df["end_zone_xT"] = xt_action_df[["x2_bin", "y2_bin"]].apply(lambda x: xt_grid_df.loc[x[1], x[0]], axis=1)

# %%
# Check the subtraction
xt_action_df["end_zone_xT"].sub(xt_action_df["start_zone_xT"])
# Out:
# 2        -0.016625
# 5         0.001032
# 6        -0.004150
# 7        -0.011240
# 8         0.024128
#             ...
# 336965    0.031858
# 336971   -0.022477
# 336972    0.046172
# 336973   -0.008829
# 336974   -0.018784
# Length: 166975, dtype: float64

# %%
# Compute xT
xt_action_df["xT"] = xt_action_df["end_zone_xT"].sub(xt_action_df["start_zone_xT"])

# %%
# Consolidate for every player individually
xt_action_df.groupby(["playerId"]).agg({"playerName": "first",
                                        "teamName": "first",
                                        "xT": "sum"})
# Out:
#                  playerName     teamName        xT
# playerId
# 4511.0         James Milner    Liverpool  0.045062
# 5583.0    Cristiano Ronaldo      Man Utd -0.014231
# 5625.0         Aaron Lennon      Burnley -0.194955
# 8166.0         Ashley Young  Aston Villa  0.739688
# 8247.0           Mark Noble     West Ham  0.314128
# ...                     ...          ...       ...
# 425603.0   Jeremy Sarmiento     Brighton  0.037457
# 425711.0       Lewis Dobbin      Everton -0.032463
# 429531.0      Kasey McAteer    Leicester -0.004138
# 429723.0      Jonathan Rowe      Norwich -0.034420
# 431283.0               Toti       Wolves  0.248975
#
# [493 rows x 3 columns]

# %%
# Consolidate for every player individually
all_players_xT = xt_action_df.groupby(["playerId"]).agg({"playerName": "first",
                                                         "teamId": "first",
                                                         "teamName": "first",
                                                         "xT": "sum"})

# %%
all_players_xT.loc[all_players_xT["xT"].nlargest(10).index]
# Out:
#                playerName  teamId        teamName         xT
# playerId
# 122117.0  Aymeric Laporte     167        Man City  10.725714
# 313171.0       Rúben Dias     167        Man City   9.529742
# 332325.0      Declan Rice      29        West Ham   9.008009
# 28550.0      Thiago Silva      15         Chelsea   8.948986
# 95408.0   Virgil van Dijk      26       Liverpool   8.357196
# 236519.0     Romain Saïss     161          Wolves   7.975870
# 104010.0  Antonio Rüdiger      15         Chelsea   7.013768
# 374631.0       Marc Guéhi     162  Crystal Palace   6.981843
# 117973.0        Eric Dier      30       Tottenham   6.545660
# 109922.0     Adam Webster     211        Brighton   6.494636

# %%
all_players_xT[["teamId", "teamName"]].drop_duplicates()
# Out:
#           teamId        teamName
# playerId
# 4511.0        26       Liverpool
# 5583.0        32         Man Utd
# 5625.0       184         Burnley
# 8166.0        24     Aston Villa
# 8247.0        29        West Ham
# 11530.0       27         Watford
# 13796.0       18     Southampton
# 16161.0      161          Wolves
# 19119.0      167        Man City
# 19545.0       14       Leicester
# 20339.0      162  Crystal Palace
# 21683.0      211        Brighton
# 22319.0      168         Norwich
# 23122.0       31         Everton
# 25604.0       30       Tottenham
# 25931.0       15         Chelsea
# 29026.0      189       Brentford
# 40027.0       23       Newcastle
# 44120.0       13         Arsenal
# 44148.0       19           Leeds

# %%
t_id = 15
t_df = all_players_xT[all_players_xT["teamId"] == t_id]
t_df.loc[t_df["xT"].nlargest(10).index]
# Out:
#                    playerName  teamId teamName        xT
# playerId
# 28550.0          Thiago Silva      15  Chelsea  8.948986
# 104010.0      Antonio Rüdiger      15  Chelsea  7.013768
# 353292.0      Trevoh Chalobah      15  Chelsea  4.868295
# 130331.0  Andreas Christensen      15  Chelsea  4.594404
# 106968.0             Jorginho      15  Chelsea  3.738027
# 93894.0         Mateo Kovacic      15  Chelsea  2.341583
# 114075.0         N'Golo Kanté      15  Chelsea  1.832776
# 255777.0   Ruben Loftus-Cheek      15  Chelsea  1.284263
# 322747.0          Malang Sarr      15  Chelsea  0.472535
# 78498.0         Romelu Lukaku      15  Chelsea  0.429090

# %%
t_df
# Out:
#                        playerName  teamId   teamName        xT
# playerId
# 4511.0               James Milner      26  Liverpool  0.045062
# 68659.0          Jordan Henderson      26  Liverpool  2.609723
# 74341.0                Joel Matip      26  Liverpool  6.320693
# 74939.0                    Thiago      26  Liverpool  3.275098
# 84146.0   Alex Oxlade-Chamberlain      26  Liverpool  0.584781
# 95408.0           Virgil van Dijk      26  Liverpool  8.357196
# 96182.0           Roberto Firmino      26  Liverpool -0.003258
# 108226.0            Mohamed Salah      26  Liverpool -3.644913
# 109915.0               Sadio Mané      26  Liverpool  0.038089
# 114147.0                  Alisson      26  Liverpool  1.155795
# 115726.0         Andrew Robertson      26  Liverpool -1.878503
# 115916.0                  Fabinho      26  Liverpool  3.126159
# 124688.0             Divock Origi      26  Liverpool  0.088547
# 136451.0             Joseph Gomez      26  Liverpool -0.012120
# 235755.0               Diogo Jota      26  Liverpool  0.805160
# 243510.0               Naby Keïta      26  Liverpool  0.880462
# 262838.0          Takumi Minamino      26  Liverpool -0.188120
# 301455.0    Konstantinos Tsimikas      26  Liverpool -1.941379
# 318871.0   Trent Alexander-Arnold      26  Liverpool -3.592081
# 322176.0        Caoimhin Kelleher      26  Liverpool -0.130647
# 345957.0          Ibrahima Konaté      26  Liverpool  2.219400
# 355354.0             Curtis Jones      26  Liverpool -0.367543
# 363982.0           Harvey Elliott      26  Liverpool -0.321365
# 386969.0            Neco Williams      26  Liverpool  0.211789
# 408662.0             Kaide Gordon      26  Liverpool -0.029956
# 425568.0             Tyler Morton      26  Liverpool  0.155522
